# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing files

# %%
state_dataset = pd.read_csv("C:\One Drive\OneDrive - Tredence\Desktop\Copy of State_Master.csv")

# %%
rs_mapping_dataset = pd.read_csv("C:\One Drive\OneDrive - Tredence\Desktop\Copy of Region_State_Mapping.csv")

# %%
region_master_dataset = pd.read_csv("C:\One Drive\OneDrive - Tredence\Desktop\Copy of Region_Master.csv")

# %%
postal_code_master_dataset = pd.read_csv("C:\One Drive\OneDrive - Tredence\Desktop\Copy of Postal_Code_Master.csv")

# %%
city_master_dataset = pd.read_csv("C:\One Drive\OneDrive - Tredence\Desktop\Copy of City_Master.csv")

# %%
sales_status_dataset = pd.read_csv("C:\One Drive\OneDrive - Tredence\Desktop\copy_of_sales_status.csv")

# %%
cs_transaction_dataset = pd.read_csv("C:\One Drive\OneDrive - Tredence\Desktop\Copy of car_sales_transactions.csv")

# %% [markdown]
# ### Viewing our data

# %%
cs_transaction_dataset
# Out:
#       Sales_ID                          Name  Year  km_Driven City_Code  \
# 0            1        Maruti Swift Dzire VDI  2014     145500      CT01
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014     120000      CT28
# 2            3      Honda City 2017-2020 EXi  2006     140000      CT12
# 3            4     Hyundai i20 Sportz Diesel  2010     127000      CT21
# 4            5        Maruti Swift VXI BSIII  2007     120000      CT03
# ...        ...                           ...   ...        ...       ...
# 7901      8124             Hyundai i20 Magna  2013     110000      CT22
# 7902      8125         Hyundai Verna CRDi SX  2007     119000      CT21
# 7903      8126        Maruti Swift Dzire ZDi  2009     120000      CT08
# 7904      8127               Tata Indigo CR4  2013      25000      CT29
# 7905      8128               Tata Indigo CR4  2013      25000      CT21
#
#      State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# ...

# %%
X_cst = cs_transaction_dataset.iloc[:,1:15]

# %%
Y_cst = cs_transaction_dataset.iloc[:,14:15]

# %%
Y_cst.shape
# Out:
# (7906, 1)

# %%
X_cst.shape
# Out:
# (7906, 14)

# %% [markdown]
# ### Encoding on transmission columns

# %%
df1 = cs_transaction_dataset

# %%
new_cst = pd.get_dummies(df1["Transmission"])

# %%
new_cst
# Out:
#       Automatic  Manual
# 0             0       1
# 1             0       1
# 2             0       1
# 3             0       1
# 4             0       1
# ...         ...     ...
# 7901          0       1
# 7902          0       1
# 7903          0       1
# 7904          0       1
# 7905          0       1
#
# [7906 rows x 2 columns]

# %%
df1.drop('Transmission',axis='columns')
# Out:
#       Sales_ID                          Name  Year  km_Driven City_Code  \
# 0            1        Maruti Swift Dzire VDI  2014     145500      CT01
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014     120000      CT28
# 2            3      Honda City 2017-2020 EXi  2006     140000      CT12
# 3            4     Hyundai i20 Sportz Diesel  2010     127000      CT21
# 4            5        Maruti Swift VXI BSIII  2007     120000      CT03
# ...        ...                           ...   ...        ...       ...
# 7901      8124             Hyundai i20 Magna  2013     110000      CT22
# 7902      8125         Hyundai Verna CRDi SX  2007     119000      CT21
# 7903      8126        Maruti Swift Dzire ZDi  2009     120000      CT08
# 7904      8127               Tata Indigo CR4  2013      25000      CT29
# 7905      8128               Tata Indigo CR4  2013      25000      CT21
#
#      State_Code  Postal_Code    Fuel Seller_Type                 Owner  \
# ...

# %%
df1['Automatic'] = new_cst['Automatic'].to_list()
df1['Manual'] = new_cst['Manual'].to_list()

# %%
df1.drop('Transmission',axis='columns')
# Out:
#       Sales_ID                          Name  Year  km_Driven City_Code  \
# 0            1        Maruti Swift Dzire VDI  2014     145500      CT01
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014     120000      CT28
# 2            3      Honda City 2017-2020 EXi  2006     140000      CT12
# 3            4     Hyundai i20 Sportz Diesel  2010     127000      CT21
# 4            5        Maruti Swift VXI BSIII  2007     120000      CT03
# ...        ...                           ...   ...        ...       ...
# 7901      8124             Hyundai i20 Magna  2013     110000      CT22
# 7902      8125         Hyundai Verna CRDi SX  2007     119000      CT21
# 7903      8126        Maruti Swift Dzire ZDi  2009     120000      CT08
# 7904      8127               Tata Indigo CR4  2013      25000      CT29
# 7905      8128               Tata Indigo CR4  2013      25000      CT21
#
#      State_Code  Postal_Code    Fuel Seller_Type                 Owner  \
# ...

# %% [markdown]
# ### Encoding Fuel column

# %%
new_cst = pd.get_dummies(df1["Fuel"])

# %%
new_cst
# Out:
#       CNG  Diesel  LPG  Petrol
# 0       0       1    0       0
# 1       0       1    0       0
# 2       0       0    0       1
# 3       0       1    0       0
# 4       0       0    0       1
# ...   ...     ...  ...     ...
# 7901    0       0    0       1
# 7902    0       1    0       0
# 7903    0       1    0       0
# 7904    0       1    0       0
# 7905    0       1    0       0
#
# [7906 rows x 4 columns]

# %%
df1['CNG'] = new_cst['CNG'].to_list()
df1['Diesel'] = new_cst['Diesel'].to_list()
df1['LPG'] = new_cst['LPG'].to_list()
df1['Petrol'] = new_cst['Petrol'].to_list()

# %%
df1.shape
# Out:
# (7906, 22)

# %%
df1 = df1.drop("Transmission",axis=1)

# %%
df1.shape
# Out:
# (7906, 22)

# %%
df1
# Out:
#       Sales_ID                          Name  Year  km_Driven City_Code  \
# 0            1        Maruti Swift Dzire VDI  2014     145500      CT01
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014     120000      CT28
# 2            3      Honda City 2017-2020 EXi  2006     140000      CT12
# 3            4     Hyundai i20 Sportz Diesel  2010     127000      CT21
# 4            5        Maruti Swift VXI BSIII  2007     120000      CT03
# ...        ...                           ...   ...        ...       ...
# 7901      8124             Hyundai i20 Magna  2013     110000      CT22
# 7902      8125         Hyundai Verna CRDi SX  2007     119000      CT21
# 7903      8126        Maruti Swift Dzire ZDi  2009     120000      CT08
# 7904      8127               Tata Indigo CR4  2013      25000      CT29
# 7905      8128               Tata Indigo CR4  2013      25000      CT21
#
#      State_Code  Postal_Code    Fuel Seller_Type                 Owner  ...  \
# ...

# %%
df1 = df1.drop("Fuel",axis=1)

# %%
df1
# Out:
#       Sales_ID                          Name  Year  km_Driven City_Code  \
# 0            1        Maruti Swift Dzire VDI  2014     145500      CT01
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014     120000      CT28
# 2            3      Honda City 2017-2020 EXi  2006     140000      CT12
# 3            4     Hyundai i20 Sportz Diesel  2010     127000      CT21
# 4            5        Maruti Swift VXI BSIII  2007     120000      CT03
# ...        ...                           ...   ...        ...       ...
# 7901      8124             Hyundai i20 Magna  2013     110000      CT22
# 7902      8125         Hyundai Verna CRDi SX  2007     119000      CT21
# 7903      8126        Maruti Swift Dzire ZDi  2009     120000      CT08
# 7904      8127               Tata Indigo CR4  2013      25000      CT29
# 7905      8128               Tata Indigo CR4  2013      25000      CT21
#
#      State_Code  Postal_Code Seller_Type                 Owner     Mileage  \
# ...

# %%
new_cst = pd.get_dummies(df1["Seller_Type"])

# %%
new_cst
# Out:
#       Dealer  Individual  Trustmark Dealer
# 0          0           1                 0
# 1          0           1                 0
# 2          0           1                 0
# 3          0           1                 0
# 4          0           1                 0
# ...      ...         ...               ...
# 7901       0           1                 0
# 7902       0           1                 0
# 7903       0           1                 0
# 7904       0           1                 0
# 7905       0           1                 0
#
# [7906 rows x 3 columns]

# %%
df1['Dealer'] = new_cst['Dealer'].to_list()
df1['Individual'] = new_cst['Individual'].to_list()
df1['Trustmark_Dealer'] = new_cst['Trustmark Dealer'].to_list()

# %%
df1 = df1.drop('Seller_Type',axis=1)

# %%
df1
# Out:
#       Sales_ID                          Name  Year  km_Driven City_Code  \
# 0            1        Maruti Swift Dzire VDI  2014     145500      CT01
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014     120000      CT28
# 2            3      Honda City 2017-2020 EXi  2006     140000      CT12
# 3            4     Hyundai i20 Sportz Diesel  2010     127000      CT21
# 4            5        Maruti Swift VXI BSIII  2007     120000      CT03
# ...        ...                           ...   ...        ...       ...
# 7901      8124             Hyundai i20 Magna  2013     110000      CT22
# 7902      8125         Hyundai Verna CRDi SX  2007     119000      CT21
# 7903      8126        Maruti Swift Dzire ZDi  2009     120000      CT08
# 7904      8127               Tata Indigo CR4  2013      25000      CT29
# 7905      8128               Tata Indigo CR4  2013      25000      CT21
#
#      State_Code  Postal_Code                 Owner     Mileage   Engine  ...  \
# ...
